# %% [markdown]
# # Исключения

# %%
import sys
import os

# %%
def mean(a):
    return sum(a) / len(a)

# %%
mean([1, 2, 3])
# Out:
# 2.0

# %%
mean([])
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-4-21c57292daaa> in <module>()
# ----> 1 mean([])
#
# <ipython-input-2-6f1d8009ce7a> in mean(a)
#       1 def mean(a):
# ----> 2     return sum(a) / len(a)
#
# ZeroDivisionError: division by zero

# %%
raise ZeroDivisionError("message")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-6-5c5256792634> in <module>()
# ----> 1 raise ZeroDivisionError("message")
#
# ZeroDivisionError: message

# %%
try:
    mean([])
except ZeroDivisionError:
    print("Error occured")
# Out:
# Error occured

# %%
try:
    mean([])
except ZeroDivisionError:
    print("Error occured")
    raise
# Out:
# Error occured
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-8-e838ebb8155d> in <module>()
#       1 try:
# ----> 2     mean([])
#       3 except ZeroDivisionError:
#       4     print("Error occured")
#       5     raise
#
# <ipython-input-2-6f1d8009ce7a> in mean(a)
#       1 def mean(a):
# ----> 2     return sum(a) / len(a)
#
# ZeroDivisionError: division by zero

# %%
try:
    mean([])
except ZeroDivisionError as e:
    print("Error occured \"{}\"".format(e))
# Out:
# Error occured "division by zero"

# %%
issubclass(ZeroDivisionError, Exception)
# Out:
# True

# %%
try:
    mean([])
except Exception as e:
    print("Error occured \"{}\"".format(e))
# Out:
# Error occured "division by zero"

# %%
try:
    mean([])
except:
    print("Error occured")
# Out:
# Error occured

# %%
try:
    mean([])
except KeyError as e:
    print("#KE Error occured \"{}\". Type: {}".format(e, type(e)))
except ZeroDivisionError as e:
    print("#ZD Error occured \"{}\". Type: {}".format(e, type(e)))
# Out:
# #ZD Error occured "division by zero". Type: <class 'ZeroDivisionError'>

# %%
# круглые скобки обязательны

try:
    mean([])
except (KeyError, TypeError, ZeroDivisionError) as e:
    print("Error occured \"{}\". Type: {}".format(e, type(e)))
    
try:
    {'key': 0.0}['value']
except (KeyError, TypeError, ZeroDivisionError) as e:
    print("Error occured \"{}\". Type: {}".format(e, type(e)))
# Out:
# Error occured "division by zero". Type: <class 'ZeroDivisionError'>
# Error occured "'value'". Type: <class 'KeyError'>

# %%
try:
    2 / 3
except ZeroDivisionError as e:
    print("Error occured \"{}\". Type: {}".format(e, type(e)))
finally:
    print("Don't worry! Be happy!")

print()

try:
    mean([])
except ZeroDivisionError as e:
    print("Error occured \"{}\". Type: {}".format(e, type(e)))
finally:
    print("That which does not kill us makes us stronger!")

print()
    
try:
    mean([])
except ZeroDivisionError as e:
    print("Error occured \"{}\". Type: {}".format(e, type(e)))
    raise e
finally:
    print("That which does not kill us makes us stronger!")
# Out:
# Don't worry! Be happy!
#
# Error occured "division by zero". Type: <class 'ZeroDivisionError'>
# That which does not kill us makes us stronger!
#
# Error occured "division by zero". Type: <class 'ZeroDivisionError'>
# That which does not kill us makes us stronger!
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-15-58c1e6147c89> in <module>()
#      21 except ZeroDivisionError as e:
#      22     print("Error occured \"{}\". Type: {}".format(e, type(e)))
# ---> 23     raise e
#      24 finally:
#      25     print("That which does not kill us makes us stronger!")
#
# <ipython-input-15-58c1e6147c89> in <module>()
#      18
#      19 try:
# ---> 20     mean([])
#      21 except ZeroDivisionError as e:
#      22     print("Error occured \"{}\". Type: {}".format(e, type(e)))
#
# <ipython-input-2-6f1d8009ce7a> in mean(a)
#       1 def mean(a):
# ----> 2     return sum(a) / len(a)
#
# ZeroDivisionError: division by zero

# %%
try:
    2 / 3
except ZeroDivisionError as e:
    print("Error occured \"{}\". Type: {}".format(e, type(e)))
else:
    print("Don't worry! Be happy!")
finally:
    print("That which does not kill us makes us stronger!")
    
print()
    
try:
    mean([])
except ZeroDivisionError as e:
    print("Error occured \"{}\". Type: {}".format(e, type(e)))
else:
    print("Don't worry! Be happy!")
finally:
    print("That which does not kill us makes us stronger!")
# Out:
# Don't worry! Be happy!
# That which does not kill us makes us stronger!
#
# Error occured "division by zero". Type: <class 'ZeroDivisionError'>
# That which does not kill us makes us stronger!

# %%
class AmigoException(ZeroDivisionError):
    """
    Custom exception
    """
    pass

# %%
try:
    mean([])
except AmigoException as e:
    print("Error occured \"{}\". Type: {}".format(e, type(e)))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-18-0487c81f8fb5> in <module>()
#       1 try:
# ----> 2     mean([])
#       3 except AmigoException as e:
#       4     print("Error occured \"{}\". Type: {}".format(e, type(e)))
#
# <ipython-input-2-6f1d8009ce7a> in mean(a)
#       1 def mean(a):
# ----> 2     return sum(a) / len(a)
#
# ZeroDivisionError: division by zero

# %%
try:
    raise AmigoException("Over all!")
except AmigoException as e:
    print("#AM Error occured \"{}\". Type: {}".format(e, type(e)))
except ZeroDivisionError as e:
    print("#ZD Error occured \"{}\". Type: {}".format(e, type(e)))
# Out:
# #AM Error occured "Over all!". Type: <class '__main__.AmigoException'>

# %%
try:
    raise AmigoException("Over all!")
except ZeroDivisionError as e:
    print("#ZD Error occured \"{}\". Type: {}".format(e, type(e)))
except AmigoException as e:
    print("#AM Error occured \"{}\". Type: {}".format(e, type(e)))
# Out:
# #ZD Error occured "Over all!". Type: <class '__main__.AmigoException'>

# %% [markdown]
# ## assert

# %%
assert True

# %%
assert 1 == 0
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-22-e99f91a18d62> in <module>()
# ----> 1 assert 1 == 0
#
# AssertionError:

# %%
assert 1 == 0, "check failed"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-23-a9c594066bfd> in <module>()
# ----> 1 assert 1 == 0, "check failed"
#
# AssertionError: check failed

# %% [markdown]
# ## Не злоупотребляй исключениями!

# %%
result = { "key": 1 }

# %%
# %%timeit

for _ in range(1000):
    try:
        res = result["bar"]
    except KeyError:
        res = 0
# Out:
# 1000 loops, best of 3: 242 µs per loop

# %%
# %%timeit

for _ in range(1000):
    res = result.get("bar", 0)
# Out:
# 10000 loops, best of 3: 119 µs per loop

# %%
# %%timeit

for _ in range(1000):
    res = result["bar"] if "bar" in result else 0
# Out:
# 10000 loops, best of 3: 107 µs per loop

# %%
from collections import defaultdict

result = defaultdict(int)
result["key"] = 1

# %%
# %%timeit

for _ in range(1000):
    res = result["bar"]
# Out:
# 10000 loops, best of 3: 62.5 µs per loop

# %% [markdown]
# # Менеджер контекста

# %%
# %%bash
#
# echo -e "Hello, world!\n1 2 3\nTrue" > /tmp/example.txt
# cat /tmp/example.txt
# Out:
# Hello, world!
# 1 2 3
# True

# %%
f_input = open('/tmp/example.txt', mode='r')
try:
    for line in f_input:
        print(line, end='')
finally:
    f_input.close()
# Out:
# Hello, world!
# 1 2 3
# True

# %%
with open('/tmp/example.txt', mode='r') as f_input:
    for line in f_input:
        print(line, end='')
        
f_input.closed
# Out:
# Hello, world!
# 1 2 3
# True
# True

# %%
try:
    with open('/tmp/example.txt', mode='r') as f_input:
        for line in f_input:
            print(line, end='')
        raise RuntimeError('All Hands on Deck!')
except RuntimeError:
    print("> Is closed:", f_input.closed)
# Out:
# Hello, world!
# 1 2 3
# True
# > Is closed: True

# %%
with open('/tmp/example.txt', mode='r') as f_input:
    with open('/tmp/output.txt', mode='w') as f_output:
        for line in f_input:
            print(line, end='', file=f_output)

# %%
# !cat /tmp/output.txt
# Out:
# Hello, world!
# 1 2 3
# True

# %%
# Либо с backslash-ом, либо на одной строке

with open('/tmp/example.txt', mode='r') as f_input, \
     open('/tmp/output.txt',  mode='w') as f_output:
        print(*f_input, sep='', end='', file=f_output)

# %%
# !cat /tmp/output.txt
# Out:
# Hello, world!
# 1 2 3
# True

# %% [markdown]
# ```python
# with open('/tmp/example.txt', mode='r') as f_input:
#     for line in f_input:
#         print(line, end='')
# ```

# %%
import sys

fd = open('/tmp/example.txt', mode='r')
f_input = fd.__enter__()

try:
    for line in f_input:
        print(line, end='')
finally:
    exc_type, exc_value, traceback = sys.exc_info()
    suppress = fd.__exit__(exc_type, exc_value, traceback)
    print(exc_type, exc_value, traceback, sep=', ')
    if exc_value is not None and not suppress:
        raise exc_value
# Out:
# Hello, world!
# 1 2 3
# True
# None, None, None

# %%
import sys

fd = open('/tmp/example.txt', mode='r')
f_input = fd.__enter__()

try:
    for line in f_input:
        print(line, end='')
    raise RuntimeError('All Hands on Deck!')
finally:
    exc_type, exc_value, traceback = sys.exc_info()
    suppress = fd.__exit__(exc_type, exc_value, traceback)
    print(exc_type, exc_value, traceback, sep=', ')
    if exc_value is not None and not suppress:
        raise exc_value
# Out:
# Hello, world!
# 1 2 3
# True
# <class 'RuntimeError'>, All Hands on Deck!, <traceback object at 0x7f07594fd788>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-52-6c99dbb48ee7> in <module>()
#      13     print(exc_type, exc_value, traceback, sep=', ')
#      14     if exc_value is not None and not suppress:
# ---> 15         raise exc_value
#
# <ipython-input-52-6c99dbb48ee7> in <module>()
#       7     for line in f_input:
#       8         print(line, end='')
# ----> 9     raise RuntimeError('All Hands on Deck!')
#      10 finally:
#      11     exc_type, exc_value, traceback = sys.exc_info()
#
# RuntimeError: All Hands on Deck!

# %% [markdown]
# ### Пример: временный файл

# %%
import os
import functools

from random import randrange


def random_string(size=7):
    def random_symbol():
        variants = [
            (ord('0'), ord('9')),
            (ord('a'), ord('z')),
        ]
        
        while True:
            i = randrange(0, len(variants))
            yield chr(randrange(*variants[i]))
        
    g = random_symbol()
    return ''.join(next(g) for i in range(size))


class TemporaryFile():
    def __init__(self, path='.', *args, **kwargs):
        self.name = os.path.join(path, 'tmp' + random_string(size=7))
        self.handler = functools.partial(open, *args, **kwargs)
        
    def __enter__(self):
        self._fd = self.handler(self.name)
        return self._fd
        
    def __exit__(self, exc_type, exc_value, traceback):
        # 1. Зачем проверка на закрытие?
        # 2. Зачем удалять атрибут?
        # 3. Почему можно обойтись без return?
        if not self._fd.closed:
            self._fd.close()
        del self._fd
        os.remove(self.name)
        

with TemporaryFile(path='/tmp/', mode='w+') as f_tmp:
    print('Hello world!', end='', file=f_tmp)
    f_tmp.seek(0)
    print(f_tmp.readline())
# Out:
# Hello world!

# %%
open(f_tmp.name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-55-91d7bfc8afad> in <module>()
# ----> 1 open(f_tmp.name)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/tmpa13l07f'

# %%
import tempfile

with tempfile.NamedTemporaryFile(mode='w+') as f_tmp:
    print('tmpfile:', f_tmp.name)
    
    f_tmp.write('Hello world!')
    f_tmp.seek(0)
    print(f_tmp.readline())
# Out:
# tmpfile: /tmp/tmpfe0ialwz
# Hello world!

# %% [markdown]
# ### Пример: подавить исключение

# %%
class SuppressException:
    def __init__(self, exc_type):
        self.exc_type = exc_type
        
    def __enter__(self):
        return self
    
    def __exit__(self, exc_type, exc_value, traceback):
        if exc_type is not None and issubclass(exc_type, self.exc_type):
            print("Keep calm, ignore exceptions.")
            return True

# %%
with SuppressException(ZeroDivisionError):
    5 / 0
# Out:
# Keep calm, ignore exceptions.

# %%
with SuppressException(ZeroDivisionError):
    raise RuntimeError()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-59-77b5aff88ae3> in <module>()
#       1 with SuppressException(ZeroDivisionError):
# ----> 2     raise RuntimeError()
#
# RuntimeError:

# %%
import contextlib

with contextlib.suppress(ValueError):
    raise ValueError

# %% [markdown]
# ## Менджер контекста для ленивых 🤔

# %%
from contextlib import contextmanager


@contextmanager
def tmpfile(path='.', *args, **kwargs):
    name = os.path.join(path, 'tmp' + random_string(size=7))
    resource = open(name, *args, **kwargs)
    
    try:
        yield resource
    finally:
        resource.close()
        os.remove(name)

# %%
with tmpfile(path='/tmp/', mode='w+') as f_tmp:
    print('Hello world!', end='', file=f_tmp)
    f_tmp.seek(0)
    print(f_tmp.readline())
# Out:
# Hello world!

# %%
open(f_tmp.name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-63-91d7bfc8afad> in <module>()
# ----> 1 open(f_tmp.name)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/tmpm1oisp8'
